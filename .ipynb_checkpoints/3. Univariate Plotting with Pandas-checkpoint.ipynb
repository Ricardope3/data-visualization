# %% [markdown]
# ![Imgur](https://i.imgur.com/K7LceOk.png)

# %%
from matplotlib import pyplot as plt

# %%
import pandas as pd

reviews = pd.read_csv("/Users/ankitsharma/Documents/Documents/Stuff/Machine Learning/Kaggle/data visualization/winemag-data_first150k.csv")

# %%
reviews
# Out:
#         Unnamed: 0      country  \
# 0                0           US
# 1                1        Spain
# 2                2           US
# 3                3           US
# 4                4       France
# 5                5        Spain
# 6                6        Spain
# 7                7        Spain
# 8                8           US
# 9                9           US
# 10              10        Italy
# 11              11           US
# 12              12           US
# 13              13       France
# 14              14           US
# 15              15           US
# 16              16           US
# 17              17        Spain
# 18              18       France
# 19              19           US
# 20              20           US
# 21              21        Spain
# 22              22        Spain
# 23              23           US
# 24              24           US
# 25              25  New Zealand
# 26              26           US
# 27              27           US
# ...

# %%
reviews.columns
# Out:
# Index(['Unnamed: 0', 'country', 'description', 'designation', 'points',
#        'price', 'province', 'region_1', 'region_2', 'variety', 'winery'],
#       dtype='object')

# %% [markdown]
# # Bar charts and categorical data
#
# Bar charts are arguably the simplest data visualization. They map categories to numbers: the amount of eggs consumed for breakfast (a category) to a number breakfast-eating Americans, for example; or, in our case, wine-producing provinces of the world (category) to the number of labels of wines they produce (number):

# %%
reviews['province'].value_counts().head(10).plot.bar()
